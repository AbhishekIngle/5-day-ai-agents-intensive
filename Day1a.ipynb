# %% [markdown]
# ### Setup
# 1. Install dependencies:
# >>python3 -m pip install google-adk
# 2. Configure Gemini API Key
# This notebook uses the [Gemini API], which requires authentication.
# Get your API key - https://aistudio.google.com/app/api-keys

# %%
import sys
print(sys.executable)
# !python --version
# Out:
# /Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/bin/python
# Python 3.11.14

# %%
import os

try:
    # Option 1: Set API key directly (NOT RECOMMENDED for production)
    GOOGLE_API_KEY = "<your_api_key>"
    
    # Option 2: Load from environment variable (RECOMMENDED)
    # GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
    
    if not GOOGLE_API_KEY:
        raise ValueError("GOOGLE_API_KEY not found. Please set it in your environment.")
    
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("Gemini API key setup complete.")
except Exception as e:
    print(
        f"Authentication Error: Please set 'GOOGLE_API_KEY' environment variable. Details: {e}"
    )
# ==================================================================================
# Out:
# Gemini API key setup complete.

# %%
#Import ADK Component
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.sessions import InMemorySessionService
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types
print("ADK components imported successfully.")
# Out:
# ADK components imported successfully.

# %%
# Hepler function
from IPython.display import display, HTML

def get_adk_local_url(port=8000):
    """
    Gets the local URL for ADK web UI.
    By default, ADK runs on http://localhost:8000
    """
    url = f"http://localhost:{port}"
    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #28a745; border-radius: 8px; background-color: #f0fdf4; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>✅ ADK Web UI Instructions</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for the server to start (you'll see "Running on..." in the output).</li>
                <li>Open your browser and navigate to the URL below, or click the link.</li>
            </ol>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI: {url} ↗
        </a>
    </div>
    """
    display(HTML(styled_html))
    return url

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# Configure Retry Options
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,  # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504]  # Retry on these HTTP errors
)
print("Retry configuration set")
# Out:
# Retry configuration set

# %% [markdown]
# ### Create AI Agent with ADK

# %%
# Define AI agent
root_agent = Agent(
    name="helpful_assistant", 
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)
print("Root Agent defined.")
# Out:
# Root Agent defined.

# %%
# Run AI Agent
runner = InMemoryRunner(agent=root_agent, app_name="agents")
print("Runner created.")
# Out:
# Runner created.

# %%
response = await runner.run_debug(
    "What is Agent Development Kit from Google? What languages is the SDK available in?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Agent Development Kit (ADK) from Google is a flexible, modular, and open-source framework designed for developing and deploying AI agents. It aims to make agent development more akin to traditional software development, allowing developers to create, deploy, and orchestrate complex agentic architectures. The ADK is optimized for Gemini and the Google ecosystem but is model-agnostic and deployment-agnostic, meaning it can be used with various AI models and deployed in different environments.
#
# The ADK supports the following programming languages for SDK development:
# *   **Python**
# *   **Java**
# *   **Go**

# %% [markdown]
# ### Try out with ADK Web Interface

# %%
# !adk create agents --model gemini-2.5-flash-lite --api_key {GOOGLE_API_KEY}
# Out:
# Agent created in /Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/agents:
# - .env
# - __init__.py
# - agent.py

# %%
# For local execution, ADK runs on localhost without a URL prefix
url_prefix = ""  # Empty string for local execution

# Display the local URL
get_adk_local_url(port=8000)
# Out:
#     <div style="padding: 15px; border: 2px solid #28a745; border-radius: 8px; background-color: #f0fdf4; margin: 20px 0;">
#         <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
#             <strong>✅ ADK Web UI Instructions</strong>
#         </div>
#         <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
#             <ol style="margin-top: 10px; padding-left: 20px;">
#                 <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
#                 <li style="margin-bottom: 5px;">Wait for the server to start (you'll see "Running on..." in the output).</li>
#                 <li>Open your browser and navigate to the URL below, or click the link.</li>
#             </ol>
#         </div>
#         <a href='http://localhost:8000' target='_blank' style="
#             display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
#             text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
#             Open ADK Web UI: http://localhost:8000 ↗
#         </a>
#     </div>
# 'http://localhost:8000'

# %%
# !adk web
# Out:
# /Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/lib/python3.11/site-packages/google/adk/cli/fast_api.py:138: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/lib/python3.11/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [88828]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:60827 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:60827 - "GET /dev-ui/ HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:60829 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:60827 - "GET /dev-ui/chunk-2WH2EVR6.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:60831 - "GET /dev-ui/main-P3SSB3YR.js HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:60831 - "GET /dev-ui/styles-DY6CQV66.css HTTP/1.1" 304 Not Modified
# INFO:     127.0.0.1:60831 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60831 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60831 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 304 Not Modified
# 2025-11-25 22:24:38,382 - INFO - adk_web_server.py:605 - New session created: 329d74ca-8328-45fb-a2a7-a0464069ee60
# INFO:     127.0.0.1:60831 - "POST /apps/agents/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60827 - "GET /builder/app/agents?ts=1764089678378 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60827 - "GET /apps/agents/users/user/sessions/329d74ca-8328-45fb-a2a7-a0464069ee60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60827 - "GET /debug/trace/session/329d74ca-8328-45fb-a2a7-a0464069ee60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60827 - "GET /apps/agents/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60827 - "GET /apps/agents/eval_sets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60831 - "GET /apps/agents/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60831 - "GET /apps/agents/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60831 - "POST /run_sse HTTP/1.1" 200 OK
# 2025-11-25 22:24:42,657 - INFO - envs.py:47 - Loaded .env file for agents at /Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/agents/.env
# 2025-11-25 22:24:42,657 - INFO - envs.py:47 - Loaded .env file for agents at /Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/agents/.env
# 2025-11-25 22:24:42,662 - INFO - agent_loader.py:127 - Found root_agent in agents.agent
# 2025-11-25 22:24:42,749 - INFO - google_llm.py:163 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 22:24:42,750 - INFO - models.py:7027 - AFC is enabled with max remote calls: 10.
# 2025-11-25 22:24:44,211 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-25 22:24:44,223 - INFO - google_llm.py:219 - Response received from the model.
# INFO:     127.0.0.1:60831 - "GET /debug/trace/session/329d74ca-8328-45fb-a2a7-a0464069ee60 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:60835 - "POST /run_sse HTTP/1.1" 200 OK
# 2025-11-25 22:24:51,166 - INFO - google_llm.py:163 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-25 22:24:51,166 - INFO - models.py:7027 - AFC is enabled with max remote calls: 10.
# 2025-11-25 22:24:52,474 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-25 22:24:52,478 - INFO - google_llm.py:219 - Response received from the model.
# INFO:     127.0.0.1:60835 - "GET /debug/trace/session/329d74ca-8328-45fb-a2a7-a0464069ee60 HTTP/1.1" 200 OK
# ^C
# INFO:     Shutting down
# INFO:     Finished server process [88828]
# 2025-11-25 22:28:15,783 - INFO - runners.py:1346 - Closing runner...
# 2025-11-25 22:28:15,783 - INFO - runners.py:1354 - Runner closed.
# ERROR:    Traceback (most recent call last):
#   File "/Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/lib/python3.11/site-packages/uvicorn/_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 641, in run_until_complete
#     self.run_forever()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/lib/python3.11/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/lib/python3.11/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/lib/python3.11/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/Users/abhishek.ingle/Documents/Abhishek/Projects/google-agent/.venv/lib/python3.11/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.14_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
#
#
# Aborted!
