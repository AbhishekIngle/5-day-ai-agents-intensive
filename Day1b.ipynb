# %% [markdown]
# ### Section 1: Multi-Agent Systems and Workflow Patterns

# %%
import os

try:
    # Option 1: Set API key directly (NOT RECOMMENDED for production)
    GOOGLE_API_KEY = "<your_api_key>"
    
    # Get from environment variable
    # GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
    
    # Validate it exists
    if not GOOGLE_API_KEY:
        raise ValueError(
            "GOOGLE_API_KEY not found. Set it with:\n"
            "  export GOOGLE_API_KEY='your_key'  (Mac/Linux)\n"
            "  set GOOGLE_API_KEY=your_key       (Windows CMD)"
        )
    
    # Set as environment variable for other libraries
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    
    print("Gemini API key setup complete.")
    
except Exception as e:
    print(f"Authentication Error: {e}")
# Out:
# Gemini API key setup complete.

# %% [markdown]
# #### Import ADK Components
#
# What These Components Do:
# 1. SequentialAgent: Runs multiple agents one after another (chain of agents)
# 2. ParallelAgent: Runs multiple agents simultaneously (concurrent execution)
# 3. LoopAgent: Runs an agent multiple times in a loop
# 4. AgentTool: Wraps another agent as a tool that can be called
# 5. FunctionTool: Wraps a Python function as a tool the agent can use

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("ADK components imported successfully.")
# Out:
# ADK components imported successfully.

# %% [markdown]
# #### Configure retry option

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)
print("Retry configuration set.")
# Out:
# Retry configuration set.

# %% [markdown]
# ### Section 2: Let's build a system with two specialized agents:
#
# 1. Research Agent - Searches for information using Google Search
# 2. Summarizer Agent - Creates concise summaries from research findings

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("research_agent created.")
# Out:
# research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("summarizer_agent created.")
# Out:
# summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("root_agent created.")
# Out:
# root_agent created.

# %% [markdown]
# #### Run the Agent and ask it about a topic

# %%
runner = InMemoryRunner(agent=root_agent, app_name="agents")
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# ResearchCoordinator > Quantum computing represents a significant leap forward with the potential to revolutionize artificial intelligence. The core advancement lies in quantum computers' ability to process information using qubits, which allow for exponentially greater processing power compared to classical computers. This enhanced capability directly addresses AI's current limitations, particularly in the vast computational resources and time required for training complex models.
#
# The implications for AI are profound and far-reaching:
#
# *   **Accelerated AI Training:** Quantum machine learning algorithms promise to drastically speed up the training of AI models by processing and analyzing large datasets much more efficiently. This could lead to AI systems that learn and adapt at unprecedented rates.
# *   **Solving Complex Problems:** Quantum computers are expected to tackle problems currently intractable for classical systems, such as complex optimization tasks. This has direct applications in fields like drug discovery, where quantum simulations could model molecular interactions with high accuracy, and in logistics, enabling real-time optimization of global supply chains.
# *   **Improved Data Processing and NLP:** Quantum enhancements could lead to more efficient data classification and significantly improve Natural Language Processing (NLP) capabilities, resulting in more sophisticated chatbots, translators, and AI assistants.
# *   **Enhanced Optimization:** Quantum algorithms are poised to improve AI optimization tasks, which is vital for areas like financial modeling, risk management, and portfolio optimization, as well as for fine-tuning existing machine learning models.
# *   **Synergistic Advancements:** The relationship is reciprocal; AI can help improve the reliability and performance of quantum systems, while quantum computing can offer more efficient data cleaning processes to benefit AI learning.
#
# Despite challenges such as achieving stable qubits and developing scalable algorithms, the field is advancing rapidly with substantial investment. The convergence of quantum computing and AI is anticipated to be a paradigm shift, driving innovation across numerous sectors.

# %% [markdown]
# ### Section 3: Sequential Workflows - The Assembly Line

# %% [markdown]
# The Problem: Unpredictable Order
#
# The previous multi-agent system worked, but it relied on a detailed instruction prompt to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.
#
# The Solution: A Fixed Pipeline
#
# When you need tasks to happen in a guaranteed, specific order, you can use a SequentialAgent. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# Use Sequential when: Order matters, you need a linear pipeline, or each step builds on the previous one.

# %% [markdown]
# Example: Blog Post Creation with Sequential Agents¶
# Let's build a system with three specialized agents:
#
# 1. Outline Agent - Creates a blog outline for a given topic
# 2. Writer Agent - Writes a blog post
# 3. Editor Agent - Edits a blog post draft for clarity and structure

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)
print("outline_agent created.")
# Out:
# outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("writer_agent created.")
# Out:
# writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("editor_agent created.")
# Out:
# editor_agent created.

# %%
# bring the agents together under a sequential agent, which runs the agents in the order that they are listed:
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("Sequential Agent created.")
# Out:
# Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent, app_name="agents")
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Multi-Agent Systems: Your Secret Weapon for Smarter Software
#
# Ever feel like your software projects are juggling too many balls? What if you could delegate tasks, enhance collaboration, and build more resilient systems without drowning in complexity? Enter Multi-Agent Systems (MAS) – a powerful paradigm that's revolutionizing how software developers approach complex problems.
#
# ### The Power of Collaboration: Why One Agent Isn't Enough
#
# *   **Decomposition of Complexity:** Break down large, intricate software problems into smaller, manageable units. Each "agent" can focus on a specific task or responsibility, making development and debugging significantly easier.
# *   **Specialization and Expertise:** Agents can be designed with specific skills and knowledge relevant to their domain. This allows for optimized performance and allows developers to leverage existing expertise rather than reinventing the wheel for every component.
# *   **Enhanced Modularity and Reusability:** Individual agents are inherently modular. This promotes cleaner code, easier maintenance, and the ability to reuse agents across different projects or even within the same project for different purposes.
#
# ### Building Smarter, More Adaptable Systems
#
# *   **Emergent Behavior:** When agents interact and communicate, they can exhibit complex, emergent behaviors that weren't explicitly programmed. This can lead to surprisingly intelligent and adaptive system-wide responses to dynamic environments.
# *   **Robustness and Resilience:** If one agent fails, the system doesn't necessarily collapse. Other agents can often compensate for the loss, making MAS inherently more fault-tolerant and reliable, especially in critical applications.
# *   **Dynamic Reconfiguration:** Agents can be added, removed, or modified at runtime without disrupting the entire system. This allows for flexible adaptation to changing requirements or environmental conditions.
#
# ### Real-World Applications for the Modern Developer
#
# *   **Complex Simulations and Modeling:** From traffic control to financial markets, MAS excel at simulating intricate systems with many interacting entities.
# *   **Smart Grids and IoT:** Optimize resource allocation, fault detection, and remote device management in distributed environments.
# *   **Robotics and Autonomous Systems:** Enable coordinated actions and intelligent decision-making for groups of robots or autonomous vehicles.
# *   **Game Development and AI:** Create more realistic and engaging non-player characters (NPCs) with sophisticated behaviors and interactions.
#
# ### Embracing the Multi-Agent Future
#
# Multi-Agent Systems are more than just a theoretical concept; they are a practical and increasingly vital tool for software developers. By embracing this paradigm, you can unlock new levels of complexity management, system intelligence, and adaptability, ultimately building software that is not just functional, but truly smart.
# WriterAgent > ## Supercharge Your Software with Multi-Agent Systems!
#
# Feeling overwhelmed by complex software projects? Imagine a team of specialized workers, each tackling a specific job, collaborating to achieve a common goal. This isn't science fiction; it's the power of Multi-Agent Systems (MAS) – a game-changer for modern developers.
#
# MAS allows you to break down daunting challenges into smaller, manageable "agents." Each agent can be designed for specific tasks and expertise, leading to cleaner code, easier debugging, and fantastic reusability. Think of it as intelligent modularity, where components are not just separate but can interact and learn.
#
# But the magic doesn't stop there. When these agents communicate, they can achieve *emergent behavior* – complex, intelligent responses that weren't explicitly programmed. This makes your systems incredibly adaptable and resilient. If one agent stumbles, others can often pick up the slack, ensuring your software keeps running smoothly. Plus, MAS allows for dynamic reconfiguration, meaning you can update or adapt your system on the fly without a complete overhaul.
#
# From simulating intricate financial markets and optimizing smart grids to enabling coordinated robots and crafting lifelike game characters, MAS is proving its worth across industries. Embracing MAS means building software that's not just functional, but truly intelligent and adaptable. Ready to build smarter?
# EditorAgent > ## Multi-Agent Systems: Your Secret Weapon for Smarter Software Development
#
# Does your software development process sometimes feel like you're juggling too many complex tasks? Imagine having a dedicated team of specialists, each expert in their own domain, working together seamlessly to achieve a common objective. This isn't a futuristic fantasy; it's the tangible power of **Multi-Agent Systems (MAS)**, a paradigm shift that's transforming how developers tackle intricate problems.
#
# ### Breaking Down Complexity, Building Smarter
#
# At its core, MAS offers a robust way to dissect daunting software challenges into smaller, more digestible "agents." Think of each agent as an independent, specialized worker. By assigning specific tasks and expertise to individual agents, you achieve several key benefits:
#
# *   **Simplified Development & Debugging:** Breaking down a large problem into smaller, self-contained agents makes each component easier to understand, develop, and debug.
# *   **Enhanced Modularity & Reusability:** Agents are naturally modular. This promotes cleaner, more maintainable code and allows for the elegant reuse of agents across different projects or within the same system for varied purposes.
# *   **Leveraging Specialization:** Agents can be designed with highly specific skills. This means you can leverage tailored expertise for optimal performance, rather than trying to create a single, monolithic solution that attempts to do everything.
#
# ### The Intelligence of Interaction: Emergence and Resilience
#
# The true magic of MAS unfolds when these agents begin to interact and collaborate. This collaborative intelligence unlocks capabilities that go far beyond traditional software design:
#
# *   **Emergent Behavior:** When agents communicate, they can collectively produce complex, sophisticated behaviors that weren't explicitly programmed into any single agent. This emergent intelligence allows systems to adapt and respond intelligently to dynamic environments.
# *   **Built-in Robustness and Resilience:** MAS architectures are inherently more fault-tolerant. If one agent encounters an issue or fails, other agents can often adapt and compensate, ensuring the overall system continues to function smoothly. This is crucial for critical applications where reliability is paramount.
# *   **Dynamic Adaptability:** MAS systems can often be reconfigured on the fly. This means you can add, remove, or update agents without needing to halt or completely overhaul the entire system, enabling flexible responses to changing requirements or environmental conditions.
#
# ### Real-World Impact Across Industries
#
# The practical applications of MAS are vast and growing:
#
# *   **Complex Simulations:** From modeling intricate financial markets and optimizing traffic flow to simulating ecological systems, MAS excel at representing and analyzing scenarios with numerous interacting components.
# *   **Smart Grids and IoT:** MAS can optimize resource distribution, enable proactive fault detection, and manage vast networks of interconnected devices in distributed environments.
# *   **Robotics and Autonomous Systems:** Coordinated swarms of robots, autonomous vehicles navigating complex terrains, and intelligent decision-making in multi-agent robotic teams are all powered by MAS principles.
# *   **Game Development and AI:** Create more believable and engaging non-player characters (NPCs) with sophisticated behaviors and realistic interactions, dramatically enhancing the player experience.
#
# ### Embrace the Future of Intelligent Software
#
# Multi-Agent Systems are no longer just a theoretical concept; they are a practical and increasingly essential tool for modern software developers. By adopting the MAS paradigm, you can unlock new levels of complexity management, build systems with inherent intelligence and adaptability, and ultimately deliver software that is not just functional, but truly smart. Ready to elevate your development game?

# %% [markdown]
# ### Section 4: Parallel Workflows - Independent Researchers

# %% [markdown]
# The Problem: The Bottleneck
#
# The previous sequential agent is great, but it's an assembly line. Each step must wait for the previous one to finish. What if you have several tasks that are not dependent on each other? For example, researching three different topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# The Solution: Concurrent Execution
#
# When you have independent tasks, you can run them all at the same time using a ParallelAgent. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.
#
# Use Parallel when: Tasks are independent, speed matters, and you can execute concurrently.

# %% [markdown]
# Example: Parallel Multi-Topic Research¶
# Let's build a system with four agents:
#
# 1. Tech Researcher - Researches AI/ML news and trends
# 2. Health Researcher - Researches recent medical news and trends
# 3. Finance Researcher - Researches finance and fintech news and trends
# 4. Aggregator Agent - Combines all research findings into a single summary

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("tech_researcher created.")
# Out:
# tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("health_researcher created.")
# Out:
# health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("finance_researcher created.")
# Out:
# finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("aggregator_agent created.")
# Out:
# aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("Parallel and Sequential Agents created.")
# Out:
# Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent, app_name="agents")
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > Here are three key AI/ML trends:
#
# 1.  **Generative AI and Multimodal Models:** AI is rapidly advancing beyond text, now creating complex content like graphics, video, and music. Companies like Google (with Gemini, Imagen, Veo) and OpenAI are at the forefront. This trend enhances creativity and practical applications across industries.
# 2.  **Agentic AI and Specialized Models:** AI systems are becoming more autonomous, capable of completing tasks with minimal human input. Simultaneously, smaller, domain-specific models are proving more effective than general ones in certain industries. This allows for highly tailored solutions and increased efficiency.
# 3.  **AI Infrastructure and Governance:** The demand for computing power, especially for generative AI, is driving innovation in AI hardware (like GPUs) and infrastructure. Alongside this, there's a growing focus on AI safety, security, ethics, and governance to ensure responsible development and deployment. Companies like NVIDIA are crucial for hardware, while firms like Google and Amazon offer integrated AI platforms.
# HealthResearcher > ## Daily Executive Briefing: Tech, Health, and Finance
#
# **Health:**
# *   **AI-powered diagnostics:** Advances in AI are enabling faster and more accurate disease detection through tools like improved imaging analysis and early identification of conditions like Alzheimer's.
# *   **Next-gen mRNA vaccines:** Building on COVID-19 success, mRNA technology is being developed for vaccines against HIV, TB, malaria, and the flu, with potential for broader applications in cancer treatment.
# *   **Personalized treatments:** Refined drug formulations and targeted therapies, such as those for specific lung cancers and HIV, are improving efficacy and reducing side effects, with some repurposed drugs showing promise.
#
# **Technology:**
# *   **Agentic AI:** AI is evolving to "virtual coworkers" capable of autonomously planning and executing complex workflows, moving beyond data analysis to action.
# *   **Advancements in robotics:** Innovations in military robotics are quickly translating to humanitarian applications, impacting disaster response, healthcare, and infrastructure within approximately two years.
# *   **Quantum computing:** Significant progress in quantum error correction suggests fault-tolerant quantum computing could be feasible by 2029, promising breakthroughs across various fields, though security implications are critical.
#
# **Finance:**
# *   **Embedded Finance:** Financial services are increasingly integrated into non-financial platforms, projected to reach $138 billion by 2026, simplifying transactions and offering contextual financial products.
# *   **DeFi Maturation:** Decentralized Finance (DeFi) protocols are becoming more secure, scalable, and regulatory-aligned, offering improved liquidity and sophisticated yield optimization tools.
# *   **AI in Finance:** AI is central to FinTech, driving personalization, improving risk decisioning, and streamlining processes. The AI market in financial services reached $115.4 billion in 2025 and is expected to double by 2029.
# FinanceResearcher > Here's a daily executive briefing on key tech, health, and finance trends:
#
# **Fintech:**
#
# *   **AI and ML Integration:** Artificial Intelligence (AI) and Machine Learning (ML) are becoming central to fintech, enhancing fraud detection, personalizing services, and improving customer interactions. The AI in fintech market is projected to grow significantly, making AI adoption a key competitive differentiator.
# *   **Payment Modernization:** Payments remain the primary growth engine for fintech, with a projected revenue of $3.1 trillion by 2028. Digital wallets and instant payment solutions are transforming transactions and cross-border money management.
# *   **Cybersecurity and Regulation:** With increasing digital transactions, cybersecurity is a paramount concern. Regulators are also evolving their oversight, leading to a focus on robust security measures and compliance.
#
# **Health Tech:**
#
# *   **AI in Diagnostics and Operations:** AI is revolutionizing healthcare through advanced diagnostics, virtual assistants, and automating administrative tasks. This aims to improve efficiency, reduce clinician burden, and enhance patient care.
# *   **Telemedicine and Remote Monitoring:** The demand for accessible care is driving the growth of telemedicine and remote patient monitoring. These technologies enable timely interventions and improve patient quality of life.
# *   **Data Interoperability and Cybersecurity:** Seamless data exchange through interoperability is critical. Concurrently, safeguarding sensitive patient data through advanced cybersecurity measures is a top priority due to rising data breaches.
#
# **Technology:**
#
# *   **Agentic AI and Autonomous Systems:** Beyond generative AI, "agentic AI" is emerging, creating virtual coworkers that can autonomously plan and execute complex workflows. This is part of a broader trend towards more adaptive and collaborative intelligent automation.
# *   **Cloud Computing and Hybrid Models:** Cloud spending continues to rise, with a growing preference for hybrid and multi-cloud solutions to enhance resilience and scalability. Pay-per-use and serverless models are gaining traction.
# *   **Cybersecurity:** As technology adoption accelerates, so do cybersecurity risks. Companies are investing in advanced security solutions, including quantum-resistant encryption, to protect against sophisticated threats.
# AggregatorAgent > ## Executive Summary: Convergence of AI, Health, and Finance
#
# The overarching trend across technology, health, and finance is the transformative impact of Artificial Intelligence (AI). **Generative AI** and increasingly **agentic AI** are reshaping industries, moving from content creation to autonomous task execution, akin to "virtual coworkers." This evolution is driving significant demand for robust **AI infrastructure**, including specialized hardware and platforms, while simultaneously highlighting the critical need for strong **AI governance, safety, and ethics**.
#
# In **healthcare**, AI is revolutionizing diagnostics, enabling faster and more accurate disease detection. Beyond AI, **mRNA technology** shows immense promise for new vaccines and cancer treatments, while **personalized medicine** is improving treatment efficacy and reducing side effects. Notably, advancements in robotics are expected to yield humanitarian benefits within two years, potentially impacting disaster response and healthcare delivery.
#
# The **finance sector** is leveraging AI for enhanced personalization, fraud detection, and risk management, with AI's market share in financial services set for significant growth. **Embedded finance** is integrating financial services seamlessly into non-financial platforms, and **DeFi** is maturing with a focus on security and regulatory alignment. Across all sectors, **cybersecurity** and data protection are paramount due to increasing digital transactions and the sensitivity of data, including health records and financial information. The emergence of **quantum computing** also presents future security implications that require proactive attention.

# %% [markdown]
# ### Section 5: Loop Workflows - The Refinement Cycle
# The Problem: One-Shot Quality
#
# All the workflows we've seen so far run from start to finish. The SequentialAgent and ParallelAgent produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.
#
# The Solution: Iterative Refinement
#
# When a task needs to be improved through cycles of feedback and revision, you can use a LoopAgent. A LoopAgent runs a set of sub-agents repeatedly until a specific condition is met or a maximum number of iterations is reached. This creates a refinement cycle, allowing the agent system to improve its own work over and over.

# %% [markdown]
# Example: Iterative Story Refinement
# Let's build a system with two agents:
#
# 1. Writer Agent - Writes a draft of a short story
# 2. Critic Agent - Reviews and critiques the short story to suggest improvements

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("initial_writer_agent created.")
# Out:
# initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("critic_agent created.")
# Out:
# critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("exit_loop function created.")
# Out:
# exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("refiner_agent created.")
# Out:
# refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("Loop and Sequential Agents created.")
# Out:
# Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent, app_name="agents")
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias polished the brass of the lantern, the rhythmic sweep of light a familiar comfort. For thirty years, the solitary tower had been his world. Tonight, however, the sea offered a different kind of illumination. A small, sealed cylinder bobbed in the surf below. He retrieved it, his weathered hands trembling slightly. Inside, not a message, but a parchment. Unfurling it, Elias gasped. It was a map, intricately drawn, but the lines pulsed with an ethereal, blue light. Islands he’d never charted, currents that defied logic, and at its heart, a symbol that hummed with an unseen energy. The storm outside raged, but inside the lighthouse, a new, far more thrilling tempest had begun.
# CriticAgent > This is a promising start to a mystery! Here are a few suggestions to enhance it:
#
# 1.  **Show, Don't Just Tell Elias's Emotions:** While you mention his "weathered hands trembling slightly" and his "gasp," consider showing Elias's internal reaction more vividly. What specific feelings does this discovery evoke in him after thirty years of routine? Is it a rush of fear, excitement, or a deep-seated longing? For instance, instead of just "Elias gasped," you could describe the breath catching in his throat, his eyes widening, or a sudden surge of adrenaline.
#
# 2.  **Enhance the Map's Mystique:** The description of the map is good, but you could lean into its otherworldly nature even further. What *kind* of ethereal blue light? Does it shift or flicker? Does the symbol at the heart radiate warmth or a strange coolness? Consider adding a sensory detail beyond sight, like a faint hum he can *feel* in his bones, or a scent associated with the parchment itself. This will make the map feel more tangible and magical.
#
# 3.  **Strengthen the Contrast Between Routine and Revelation:** You establish Elias's thirty years of solitude well. To amplify the impact of the map, you could briefly hint at the *nature* of that routine before the discovery. What does his typical night entail? This will make the "thrilling tempest" brewing inside him feel even more significant by highlighting the stark contrast with his established, predictable life.
# RefinerAgent > Elias meticulously polished the brass of the lantern, its rhythmic sweep of light a familiar, almost monotonous, comfort. For thirty years, this solitary tower, with its predictable cycle of polishing, oiling, and solitary meals, had been his entire world. Tonight, however, the usual cadence of crashing waves was broken by an unusual visitor. The sea, in its own turbulent way, offered a different kind of illumination. A small, sealed cylinder bobbed erratically in the surf below.
#
# He retrieved it, his weathered hands, usually steady from decades of routine, trembling with an unfamiliar urgency. Inside, not a message, but a parchment. As he carefully unfurled it, the breath hitched in his throat, his eyes widening in disbelief. It was a map, intricately drawn, but the lines weren't mere ink; they pulsed with an ethereal, electric blue light that seemed to shift and flicker like captured lightning. Islands he’d never charted, swirling currents that defied all known logic, and at its heart, a symbol that didn't just hum with unseen energy, but vibrated deep within his bones, a strange coolness emanating from it. The storm outside, a familiar fury of wind and rain, suddenly seemed a pale imitation of the exhilarating, terrifying tempest that had just begun to brew within the quiet confines of his soul.
# CriticAgent > APPROVED
